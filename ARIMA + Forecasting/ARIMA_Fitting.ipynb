# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
import scipy as sp
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from scipy.signal import detrend

# %%
ar_df_1 = pd.read_csv('arma_series01.csv')
ar_df_1.head()
# Out:
#         Date       Y
# 0  01MAY1992  100.04
# 1  01JUN1992  100.32
# 2  01JUL1992  100.16
# 3  01AUG1992  100.24
# 4  01SEP1992  100.14

# %%
ar_df_1['DATE'] = pd.to_datetime(ar_df_1['Date'], format='%d%b%Y')

ar_ts_1 = pd.Series(ar_df_1['Y'].values, index=ar_df_1['DATE'])

ar_ts_1.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))

plot_acf(ar_ts_1, ax=ax1, zero=False)
plot_pacf(ar_ts_1, ax=ax2, zero=False)
plt.show()

# %%
sm.stats.acorr_ljungbox(ar_ts_1, lags=[10], return_df=True)
# Out:
#       lb_stat     lb_pvalue
# 10  83.341864  1.107480e-13

# %%
adfuller(ar_ts_1, regression='c')
# Out:
# (-7.740472471884697,
#  1.0652730156324102e-11,
#  0,
#  199,
#  {'1%': -3.4636447617687436,
#   '5%': -2.8761761179270766,
#   '10%': -2.57457158581854},
#  -348.6741669523335)

# %%
fit_ar1 = ARIMA(ar_ts_1, order=(1,0,0)).fit()

print(fit_ar1.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  200
# Model:                 ARIMA(1, 0, 0)   Log Likelihood                 187.426
# Date:                Tue, 01 Oct 2024   AIC                           -368.852
# Time:                        14:08:19   BIC                           -358.957
# Sample:                    05-01-1992   HQIC                          -364.847
#                          - 12-01-2008
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        100.0149      0.014   6978.834      0.000      99.987     100.043
# ar.L1          0.5275      0.067      7.863      0.000       0.396       0.659
# sigma2         0.0090      0.001      9.902      0.000       0.007       0.011
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 1.38
# Prob(Q):                              0.96   Prob(JB):                         0.50
# Heteroskedasticity (H):               0.76   Skew:                             0.20
# Prob(H) (two-sided):                  0.26   Kurtosis:                         3.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
residuals = fit_ar1.resid
plt.plot(residuals)
plt.title('Residual Plot')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))

plot_acf(residuals, ax=ax1, zero=False)
plot_pacf(residuals, ax=ax2, zero=False)
plt.show()

# %%
sm.stats.acorr_ljungbox(residuals, lags=[10], return_df=True)
# Out:
#      lb_stat  lb_pvalue
# 10  4.384759   0.928325

# %%
ar_df_2 = pd.read_csv('arma_series02.csv')
ar_df_2.head()
# Out:
#         Date       Y
# 0  15JUN2008   98.02
# 1  16JUN2008  100.34
# 2  17JUN2008   99.36
# 3  18JUN2008  100.84
# 4  19JUN2008  100.26

# %%
ar_df_2['DATE'] = pd.to_datetime(ar_df_2['Date'], format='%d%b%Y')

ar_ts_2 = pd.Series(ar_df_2['Y'].values, index=ar_df_2['DATE'])

ar_ts_2.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))

plot_acf(ar_ts_2, ax=ax1, zero=False)
plot_pacf(ar_ts_2, ax=ax2, zero=False)
plt.show()

# %%
sm.stats.acorr_ljungbox(ar_ts_2, lags=[10], return_df=True)
# Out:
#       lb_stat      lb_pvalue
# 10  563.14271  1.378632e-114

# %%
adfuller(ar_ts_2, regression='c')
# Out:
# (-2.8620574499646,
#  0.0499414543060636,
#  1,
#  198,
#  {'1%': -3.4638151713286316,
#   '5%': -2.876250632135043,
#   '10%': -2.574611347821651},
#  417.4713510923384)

# %%
fit_ar2 = ARIMA(ar_ts_2, order=(2,0,0)).fit()

print(fit_ar2.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  200
# Model:                 ARIMA(2, 0, 0)   Log Likelihood                -227.765
# Date:                Tue, 01 Oct 2024   AIC                            463.530
# Time:                        14:08:20   BIC                            476.723
# Sample:                    06-15-2008   HQIC                           468.869
#                          - 12-31-2008
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        100.1927      0.358    280.155      0.000      99.492     100.894
# ar.L1          0.5332      0.071      7.489      0.000       0.394       0.673
# ar.L2          0.3309      0.068      4.838      0.000       0.197       0.465
# sigma2         0.5675      0.065      8.760      0.000       0.441       0.695
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.12   Jarque-Bera (JB):                 1.32
# Prob(Q):                              0.73   Prob(JB):                         0.52
# Heteroskedasticity (H):               0.80   Skew:                             0.13
# Prob(H) (two-sided):                  0.38   Kurtosis:                         2.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
residuals = fit_ar2.resid
plt.plot(residuals)
plt.title('Residual Plot')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))

plot_acf(residuals, ax=ax1, zero=False)
plot_pacf(residuals, ax=ax2, zero=False)
plt.show()

# %%
sm.stats.acorr_ljungbox(residuals, lags=[10], return_df=True)
# Out:
#      lb_stat  lb_pvalue
# 10  6.843747   0.740109

# %%
ar_df_3 = pd.read_csv('arma_series03.csv')
ar_df_3.head()
# Out:
#         Date       Y
# 0  01MAY1992  100.08
# 1  01JUN1992  100.24
# 2  01JUL1992   99.79
# 3  01AUG1992  100.16
# 4  01SEP1992   99.91

# %%
ar_df_3['DATE'] = pd.to_datetime(ar_df_3['Date'], format='%d%b%Y')

ar_ts_3 = pd.Series(ar_df_3['Y'].values, index=ar_df_3['DATE'])

ar_ts_3.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))

plot_acf(ar_ts_3, ax=ax1, zero=False)
plot_pacf(ar_ts_3, ax=ax2, zero=False)
plt.show()

# %%
fit_ar3 = ARIMA(ar_ts_3, order=(0,0,1)).fit()

print(fit_ar3.summary())
# Out:
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  200
# Model:                 ARIMA(0, 0, 1)   Log Likelihood                 189.468
# Date:                Tue, 01 Oct 2024   AIC                           -372.936
# Time:                        14:08:21   BIC                           -363.041
# Sample:                    05-01-1992   HQIC                          -368.932
#                          - 12-01-2008
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        100.0016      0.002    4.5e+04      0.000      99.997     100.006
# ma.L1         -0.6738      0.058    -11.580      0.000      -0.788      -0.560
# sigma2         0.0088      0.001      9.472      0.000       0.007       0.011
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 1.10
# Prob(Q):                              0.98   Prob(JB):                         0.58
# Heteroskedasticity (H):               0.78   Skew:                             0.16
# Prob(H) (two-sided):                  0.31   Kurtosis:                         2.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
residuals = fit_ar3.resid
plt.plot(residuals)
plt.title('Residual Plot')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))

plot_acf(residuals, ax=ax1, zero=False)
plot_pacf(residuals, ax=ax2, zero=False)
plt.show()

# %%
sm.stats.acorr_ljungbox(residuals, lags=[10], return_df=True)
# Out:
#      lb_stat  lb_pvalue
# 10  3.800108   0.955914

# %%
ar_df_4 = pd.read_csv('arma_series04.csv')
ar_df_4.head()
# Out:
#         Date       Y
# 0  08MAY2005  200.73
# 1  09MAY2005  202.07
# 2  10MAY2005  198.22
# 3  11MAY2005  200.57
# 4  12MAY2005  199.43

# %%
ar_df_4['DATE'] = pd.to_datetime(ar_df_4['Date'], format='%d%b%Y')

ar_ts_4 = pd.Series(ar_df_4['Y'].values, index=ar_df_4['DATE'])

ar_ts_4.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))

plot_acf(ar_ts_4, ax=ax1, zero=False)
plot_pacf(ar_ts_4, ax=ax2, zero=False)
plt.show()

# %%
adfuller(ar_ts_4, regression='c')
# Out:
# (-9.470803042774545,
#  4.1113551641336666e-16,
#  5,
#  194,
#  {'1%': -3.4645146202692527,
#   '5%': -2.8765564361715534,
#   '10%': -2.5747745328940375},
#  446.9913032265908)

# %%
fit_ar4 = ARIMA(ar_ts_4, order=(2,0,1)).fit()

print(fit_ar4.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  200
# Model:                 ARIMA(2, 0, 1)   Log Likelihood                -239.220
# Date:                Tue, 01 Oct 2024   AIC                            488.441
# Time:                        14:08:23   BIC                            504.932
# Sample:                    05-08-2005   HQIC                           495.115
#                          - 11-23-2005
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        200.0059      0.012    1.7e+04      0.000     199.983     200.029
# ar.L1          0.2370      0.097      2.447      0.014       0.047       0.427
# ar.L2         -0.1916      0.083     -2.298      0.022      -0.355      -0.028
# ma.L1         -0.8094      0.068    -11.969      0.000      -0.942      -0.677
# sigma2         0.6371      0.067      9.494      0.000       0.506       0.769
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 0.42
# Prob(Q):                              0.92   Prob(JB):                         0.81
# Heteroskedasticity (H):               0.77   Skew:                             0.10
# Prob(H) (two-sided):                  0.29   Kurtosis:                         2.90
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
residuals = fit_ar4.resid
plt.plot(residuals)
plt.title('Residual Plot')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))

plot_acf(residuals, ax=ax1, zero=False)
plot_pacf(residuals, ax=ax2, zero=False)
plt.show()

# %%
sm.stats.acorr_ljungbox(residuals, lags=[10], return_df=True)
# Out:
#     lb_stat  lb_pvalue
# 10  2.83958   0.984951

# %%
ar_df_5 = pd.read_csv('arma_series05.csv')
ar_df_5.head()
# Out:
#         Date       Y
# 0  01MAY1992   99.79
# 1  01JUN1992  102.14
# 2  01JUL1992   99.94
# 3  01AUG1992  102.47
# 4  01SEP1992  100.80

# %%
ar_df_5['DATE'] = pd.to_datetime(ar_df_5['Date'], format='%d%b%Y')

ar_ts_5 = pd.Series(ar_df_5['Y'].values, index=ar_df_5['DATE'])

ar_ts_5.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))

plot_acf(ar_ts_5, ax=ax1, zero=False)
plot_pacf(ar_ts_5, ax=ax2, zero=False)
plt.show()

# %%
adfuller(ar_ts_5, regression='c')
# Out:
# (-4.242887708839928,
#  0.000557006961531736,
#  2,
#  197,
#  {'1%': -3.463987334463603,
#   '5%': -2.8763259091636213,
#   '10%': -2.5746515171738515},
#  463.7134902683071)

# %%
fit_ar5 = ARIMA(ar_ts_5, order=(1,0,2)).fit()

print(fit_ar5.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  200
# Model:                 ARIMA(1, 0, 2)   Log Likelihood                -249.546
# Date:                Tue, 01 Oct 2024   AIC                            509.092
# Time:                        14:08:24   BIC                            525.584
# Sample:                    05-01-1992   HQIC                           515.766
#                          - 12-01-2008
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        100.1364      0.139    722.880      0.000      99.865     100.408
# ar.L1          0.6913      0.097      7.147      0.000       0.502       0.881
# ma.L1         -0.6736      0.108     -6.241      0.000      -0.885      -0.462
# ma.L2          0.3954      0.071      5.584      0.000       0.257       0.534
# sigma2         0.7079      0.078      9.107      0.000       0.556       0.860
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 0.85
# Prob(Q):                              0.93   Prob(JB):                         0.65
# Heteroskedasticity (H):               0.79   Skew:                             0.13
# Prob(H) (two-sided):                  0.33   Kurtosis:                         2.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
residuals = fit_ar5.resid
plt.plot(residuals)
plt.title('Residual Plot')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))

plot_acf(residuals, ax=ax1, zero=False)
plot_pacf(residuals, ax=ax2, zero=False)
plt.show()

# %%
sm.stats.acorr_ljungbox(residuals, lags=[10], return_df=True)
# Out:
#      lb_stat  lb_pvalue
# 10  3.459053    0.96847

# %%
ar_df_6 = pd.read_csv('arma_series06.csv')
ar_df_6.head()
# Out:
#         Date       Y
# 0  01MAY1992  101.02
# 1  01JUN1992  102.08
# 2  01JUL1992   98.84
# 3  01AUG1992   99.94
# 4  01SEP1992   99.66

# %%
ar_df_6['DATE'] = pd.to_datetime(ar_df_6['Date'], format='%d%b%Y')

ar_ts_6 = pd.Series(ar_df_6['Y'].values, index=ar_df_6['DATE'])

ar_ts_6.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))

plot_acf(ar_ts_6, ax=ax1, zero=False)
plot_pacf(ar_ts_6, ax=ax2, zero=False)
plt.show()

# %%
adfuller(ar_ts_6, regression='c')
# Out:
# (-8.691877273473832,
#  4.02014037219067e-14,
#  5,
#  194,
#  {'1%': -3.4645146202692527,
#   '5%': -2.8765564361715534,
#   '10%': -2.5747745328940375},
#  444.0785689829912)

# %%
fit_ar6 = ARIMA(ar_ts_6, order=(2,0,1)).fit()

print(fit_ar6.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  200
# Model:                 ARIMA(2, 0, 1)   Log Likelihood                -237.930
# Date:                Tue, 01 Oct 2024   AIC                            485.860
# Time:                        14:08:25   BIC                            502.351
# Sample:                    05-01-1992   HQIC                           492.534
#                          - 12-01-2008
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        100.0156      0.023   4342.298      0.000      99.970     100.061
# ar.L1          0.4127      0.105      3.914      0.000       0.206       0.619
# ar.L2         -0.4411      0.068     -6.446      0.000      -0.575      -0.307
# ma.L1         -0.5936      0.102     -5.809      0.000      -0.794      -0.393
# sigma2         0.6298      0.068      9.310      0.000       0.497       0.762
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                 0.68
# Prob(Q):                              0.88   Prob(JB):                         0.71
# Heteroskedasticity (H):               0.78   Skew:                             0.10
# Prob(H) (two-sided):                  0.32   Kurtosis:                         2.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
residuals = fit_ar6.resid
plt.plot(residuals)
plt.title('Residual Plot')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))

plot_acf(residuals, ax=ax1, zero=False)
plot_pacf(residuals, ax=ax2, zero=False)
plt.show()

# %%
sm.stats.acorr_ljungbox(residuals, lags=[10], return_df=True)
# Out:
#      lb_stat  lb_pvalue
# 10  2.614681   0.989097

# %%
ar_df_7 = pd.read_csv('arma_series07.csv')
ar_df_7.head()
# Out:
#         Date       Y
# 0  01JAN1993  133.14
# 1  01FEB1993  133.01
# 2  01MAR1993  132.61
# 3  01APR1993  133.68
# 4  01MAY1993  133.92

# %%
ar_df_7['DATE'] = pd.to_datetime(ar_df_7['Date'], format='%d%b%Y')

ar_ts_7 = pd.Series(ar_df_7['Y'].values, index=ar_df_7['DATE'])

ar_ts_7.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))

plot_acf(ar_ts_7, ax=ax1, zero=False)
plot_pacf(ar_ts_7, ax=ax2, zero=False)
plt.show()

# %%
adfuller(ar_ts_7, regression='c')
# Out:
# (-3.5198181399540034,
#  0.007492472984182891,
#  4,
#  187,
#  {'1%': -3.465811691080702,
#   '5%': -2.877123351472649,
#   '10%': -2.5750770662586864},
#  568.4211241981385)

# %%
fit_ar7= ARIMA(ar_ts_7, order=(1,0,1)).fit()

print(fit_ar7.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  192
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -305.941
# Date:                Tue, 01 Oct 2024   AIC                            619.883
# Time:                        14:10:03   BIC                            632.913
# Sample:                    01-01-1993   HQIC                           625.160
#                          - 12-01-2008
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        135.9223      0.662    205.250      0.000     134.624     137.220
# ar.L1          0.7965      0.047     16.837      0.000       0.704       0.889
# ma.L1          0.6029      0.070      8.588      0.000       0.465       0.740
# sigma2         1.4012      0.131     10.718      0.000       1.145       1.657
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 1.33
# Prob(Q):                              0.98   Prob(JB):                         0.51
# Heteroskedasticity (H):               0.81   Skew:                             0.02
# Prob(H) (two-sided):                  0.39   Kurtosis:                         3.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\trush\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
residuals = fit_ar7.resid
plt.plot(residuals)
plt.title('Residual Plot')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,12))

plot_acf(residuals, ax=ax1, zero=False)
plot_pacf(residuals, ax=ax2, zero=False)
plt.show()

# %%
sm.stats.acorr_ljungbox(residuals, lags=[10], return_df=True)
# Out:
#      lb_stat  lb_pvalue
# 10  8.041095   0.624823
